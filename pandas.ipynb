# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhil7127/AIO/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Pokemon.csv")

# %%
dataFrame = pd.DataFrame({"Name":["nikhil","varma","bye"],"Age":[10,20,30],'Sex':[np.nan,"male","female"]})

# %%
dataFrame
# Out:
#      Name  Age     Sex
# 0  nikhil   10     NaN
# 1   varma   20    male
# 2     bye   30  female

# %%
dataFrame.dtypes
# Out:
# Name    object
# Age      int64
# Sex     object
# dtype: object

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name','Type 1']].head()
# Out:
#                     Name Type 1
# 0              Bulbasaur  Grass
# 1                Ivysaur  Grass
# 2               Venusaur  Grass
# 3  VenusaurMega Venusaur  Grass
# 4             Charmander   Fire

# %%
df.iloc[1:10,[1,2,3,9]]
# Out:
#                         Name Type 1  Type 2  Sp. Def
# 1                    Ivysaur  Grass  Poison       80
# 2                   Venusaur  Grass  Poison      100
# 3      VenusaurMega Venusaur  Grass  Poison      120
# 4                 Charmander   Fire     NaN       50
# 5                 Charmeleon   Fire     NaN       65
# 6                  Charizard   Fire  Flying       85
# 7  CharizardMega Charizard X   Fire  Dragon       85
# 8  CharizardMega Charizard Y   Fire  Flying      115
# 9                   Squirtle  Water     NaN       64

# %%
for index, value in df.iterrows():
  print(index,value['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran♀
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran♂
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# ...

# %%
df.loc[df["Name"] == "Sliggoo"]
# Out:
#        #     Name  Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 775  705  Sliggoo  Dragon    NaN  ...      113     60           6      False
#
# [1 rows x 13 columns]

# %%
df.describe()
# Out:
#                 #      Total          HP  ...     Sp. Def       Speed  Generation
# count  800.000000  800.00000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750  435.10250   69.258750  ...   71.902500   68.277500     3.32375
# std    208.343798  119.96304   25.534669  ...   27.828916   29.060474     1.66129
# min      1.000000  180.00000    1.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000  330.00000   50.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000  450.00000   65.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000  515.00000   80.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  780.00000  255.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 9 columns]

# %%
df.sort_values(["Name","Type 1"],ascending=[1,0])
# Out:
#        #                     Name   Type 1  ... Speed  Generation  Legendary
# 510  460                Abomasnow    Grass  ...    60           4      False
# 511  460  AbomasnowMega Abomasnow    Grass  ...    30           4      False
# 68    63                     Abra  Psychic  ...    90           1      False
# 392  359                    Absol     Dark  ...    75           3      False
# 393  359          AbsolMega Absol     Dark  ...   115           3      False
# ..   ...                      ...      ...  ...   ...         ...        ...
# 632  571                  Zoroark     Dark  ...   105           5      False
# 631  570                    Zorua     Dark  ...    65           5      False
# 46    41                    Zubat   Poison  ...    55           1      False
# 695  634                 Zweilous     Dark  ...    58           5      False
# 794  718         Zygarde50% Forme   Dragon  ...    95           6       True
#
# [800 rows x 13 columns]

# %%
df['New'] = "nikhil"
df['Total'] = df.iloc[:,5:10].sum(axis=1)

# %%
df.head(2)
# Out:
#    #       Name Type 1  Type 2  ...  Speed  Generation  Legendary     New
# 0  1  Bulbasaur  Grass  Poison  ...     45           1      False  nikhil
# 1  2    Ivysaur  Grass  Poison  ...     60           1      False  nikhil
#
# [2 rows x 14 columns]

# %%
df.drop(columns=["New",'Total']).head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
newData = df[["Name","Type 1","Type 2"]]

# %%
newData.head(2)
# Out:
#         Name Type 1  Type 2
# 0  Bulbasaur  Grass  Poison
# 1    Ivysaur  Grass  Poison

# %%
col= list(df.columns)

# %%
df[col[3:]+col[1:3]].head(1)
# Out:
#    Type 2  Total  HP  Attack  ...  Legendary     New       Name  Type 1
# 0  Poison    273  45      49  ...      False  nikhil  Bulbasaur   Grass
#
# [1 rows x 13 columns]

# %%
filter = df.loc[(df['HP'] > 50) & (df["HP"] < 100)]

# %%
filter.reset_index(inplace=True)

# %%
filter.drop(columns="#").head(2)
# Out:
#    index      Name Type 1  Type 2  ...  Speed  Generation  Legendary     New
# 0      1   Ivysaur  Grass  Poison  ...     60           1      False  nikhil
# 1      2  Venusaur  Grass  Poison  ...     80           1      False  nikhil
#
# [2 rows x 14 columns]

# %%
filter.loc[~filter['Name'].str.contains('Mega')].head(2)
# Out:
#    index  #      Name Type 1  ... Speed  Generation  Legendary     New
# 0      1  2   Ivysaur  Grass  ...    60           1      False  nikhil
# 1      2  3  Venusaur  Grass  ...    80           1      False  nikhil
#
# [2 rows x 15 columns]

# %%
filter.loc[filter['Type 1'].str.contains("Poison|Grass")] # we can stop using regex by saying contains(regex = False)
# we can using contains(flags=re.I) for not casesensitive
# Out:
#      index    #                   Name  ... Generation Legendary     New
# 0        1    2                Ivysaur  ...          1     False  nikhil
# 1        2    3               Venusaur  ...          1     False  nikhil
# 2        3    3  VenusaurMega Venusaur  ...          1     False  nikhil
# 18      29   24                  Arbok  ...          1     False  nikhil
# 21      34   29               Nidoran♀  ...          1     False  nikhil
# ..     ...  ...                    ...  ...        ...       ...     ...
# 434    718  650                Chespin  ...          6     False  nikhil
# 435    719  651              Quilladin  ...          6     False  nikhil
# 436    720  652             Chesnaught  ...          6     False  nikhil
# 449    740  672                 Skiddo  ...          6     False  nikhil
# 465    761  691               Dragalge  ...          6     False  nikhil
#
# [64 rows x 15 columns]

# %%
filter.loc[filter["Type 1"] == "Grass",['HP',"Attack"]] = [10,20]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1758: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, v)

# %%
filter.head(3)
# Out:
#    index  #                   Name Type 1  ... Speed  Generation  Legendary     New
# 0      1  2                Ivysaur  Grass  ...    60           1      False  nikhil
# 1      2  3               Venusaur  Grass  ...    80           1      False  nikhil
# 2      3  3  VenusaurMega Venusaur  Grass  ...    80           1      False  nikhil
#
# [3 rows x 15 columns]

# %% [markdown]
# ### GROUP BY

# %%
filter.groupby(["Type 1"]).mean()[["Attack"]]
# Out:
#               Attack
# Type 1
# Bug        89.547619
# Dark       93.450000
# Dragon    105.111111
# Electric   78.481481
# Fairy      63.333333
# Fighting  101.437500
# Fire       90.527778
# Flying     95.000000
# Ghost      78.647059
# Grass      20.000000
# Ground     94.647059
# Ice        75.062500
# Normal     78.017241
# Poison     80.705882
# Psychic    68.322581
# Rock       99.214286
# Steel      96.473684
# Water      79.333333
